# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Read Dataset
dataset = pd.read_csv('insurance_pre.csv')
#print(dataset)

dataset=pd.get_dummies(dataset,drop_first=True)
#print(dataset)

indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['mse', 'absolute_error'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
# Fitting the model for grid search
grid.fit(X_train, y_train)

# print best parameter after tuning
print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)

# print classification report
from sklearn.metrics import r2_score
r_score = r2_score(y_test,grid_predictions)

print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)

table = pd.DataFrame.from_dict(re)
table
#print(table)

age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))

Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
#
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.839 total time=   0.5s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.827 total time=   0.5s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.760 total time=   0.5s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.775 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.719 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=10;, score=0.759 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.802 total time=   0.4s
# [CV 2/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.773 total time=   0.4s
# [CV 3/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.840 total time=   0.5s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.829 total time=   0.5s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.765 total time=   0.5s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.748 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.741 total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.828 total time=   0.5s
# [CV 5/5] END criterion=absolute_error, max_features=sqrt, n_estimators=100;, score=0.764 total time=   0.4s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.796 total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.735 total time=   0.1s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.839 total time=   0.1s
# [CV 4/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.786 total time=   0.0s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=10;, score=0.760 total time=   0.1s
# [CV 1/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.800 total time=   0.5s
# [CV 3/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.837 total time=   0.4s
# [CV 5/5] END criterion=absolute_error, max_features=log2, n_estimators=100;, score=0.762 total time=   0.4s
# [CV 2/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=sqrt, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_features=log2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/5] END criterion=absolute_error, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# /home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'absolute_error', 'poisson', 'friedman_mse'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'friedman_mse', 'absolute_error'}. Got 'mse' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/kumar/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.78025243 0.79930032 0.77683155 0.80097967]
#   warnings.warn(
# {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8744358053638333
# Age: 43
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1
# Future_Prediction=[46990.61684705]
